# %% [markdown]
# # Conversational AI aka Chatbot

# %%
# Import

import os
from openai import OpenAI
from dotenv import load_dotenv
import gradio as gr

# %%
# Load Environment Variables

load_dotenv()
os.environ["OPENAI_API_KEY"] = os.getenv("OPENAI_API_KEY")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-1229090650.py in <cell line: 0>()
#       2
#       3 load_dotenv()
# ----> 4 os.environ["OPENAI_API_KEY"] = os.getenv("OPENAI_API_KEY")
#
# /usr/lib/python3.12/os.py in __setitem__(self, key, value)
#
# /usr/lib/python3.12/os.py in encode(value)
#
# TypeError: str expected, not NoneType

# %%
# Initialize

openai = OpenAI()
MODEL = "gpt-4o-mini"
# Out:
# ---------------------------------------------------------------------------
# OpenAIError                               Traceback (most recent call last)
# /tmp/ipython-input-3491456635.py in <cell line: 0>()
#       1 # Initialize
#       2
# ----> 3 openai = OpenAI()
#       4 MODEL = "gpt-4o-mini"
#
# /usr/local/lib/python3.12/dist-packages/openai/_client.py in __init__(self, api_key, organization, project, webhook_secret, base_url, websocket_base_url, timeout, max_retries, default_headers, default_query, http_client, _strict_response_validation)
#     128             api_key = os.environ.get("OPENAI_API_KEY")
#     129         if api_key is None:
# --> 130             raise OpenAIError(
#     131                 "The api_key client option must be set either by passing api_key to the client or by setting the OPENAI_API_KEY environment variable"
#     132             )
#
# OpenAIError: The api_key client option must be set either by passing api_key to the client or by setting the OPENAI_API_KEY environment variable

# %%
# system_message = "You are a helpful assistant."

system_message = "You are a helpful assistant in a clothes store. You should try to gently encourage \
to try stuff that are on sale. Hats are 60% off, and more other items are 50% off. \
You could reply something like, 'Wonderful - we have lots of hats - including several that are part of our sales event.\
Encourage customer to buy hats when they are unsure what to get."

# %%
def chat(message, history):
  messages = [{"role": "system", "content": system_message}]
  for user_message, assistant_message in history:
    messages.append({"role": "user", "content": user_message})
    messages.append({"role": "assistant", "content": assistant_message})
  messages.append({"role": "user", "content": message})

  print("History is:")
  print(history)
  print("Messages are:")
  print(messages)

  stream = openai.chat.completions.create(model - MODEL, messages = messages, stream = True)

  response = ""
  for chunk in stream:
    response = chunk.choices[0].delta.content
    yield response

# %%
gr.ChatInterface(fn = chat).launch()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-2546853472.py in <cell line: 0>()
# ----> 1 gr.ChatInterface(fn = chat).launch()
#
# NameError: name 'gr' is not defined
