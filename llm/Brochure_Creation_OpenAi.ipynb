# %% [markdown]
# # Brochure_Creation_OpenAi
# Create a product that builds a Brochure for a company to be used for prospective clients, investors and potential recruits.
#
# We will be provided a company name and their primary website.

# %%
# imports
# If these fail, please check you're running from an 'activated' environment in the command prompt

import os
import requests
import json
from typing import List
from dotenv import load_dotenv
from bs4 import BeautifulSoup
from IPython.display import Markdown, display, update_display
from openai import OpenAI

# %%
load_dotenv(override=True)
api_key = os.getenv('OPENAI_API_KEY')

if api_key and api_key.startswith('sk-proj-') and len(api_key)>10:
    print("API key looks good so far")
else:
    print("There might be a problem with your API key?")
    
MODEL = 'gpt-4o-mini'
openai = OpenAI()
# Out:
# API key looks good so far

# %%
# A class to represent a Webpage

# Some websites need you to use proper headers when fetching them:
headers = {
 "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/117.0.0.0 Safari/537.36"
}

class Website:
    """
    A utility class to represent a Website that we have scraped, now with links
    """

    def __init__(self, url):
        self.url = url
        response = requests.get(url, headers=headers)
        self.body = response.content
        soup = BeautifulSoup(self.body, 'html.parser')
        self.title = soup.title.string if soup.title else "No title found"
        if soup.body:
            for irrelevant in soup.body(["script", "style", "img", "input"]):
                irrelevant.decompose()
            self.text = soup.body.get_text(separator="\n", strip=True)
        else:
            self.text = ""
        links = [link.get('href') for link in soup.find_all('a')]
        self.links = [link for link in links if link]

    def get_contents(self):
        return f"Webpage Title:\n{self.title}\nWebpage Contents:\n{self.text}\n\n"

# %% [markdown]
# ## First step: Have GPT-4o-mini figure out which links are relevant
#
# ---
#
#
#
# ### Use a call to gpt-4o-mini to read the links on a webpage, and respond in structured JSON.
# It should decide which links are relevant, and replace relative links such as "/about" with "https://company.com/about".
# We will use "one shot prompting" in which we provide an example of how it should respond in the prompt.

# %%
link_system_prompt = "You are provided with a list of links found on a webpage. \
You are able to decide which of the links would be most relevant to include in a brochure about the company, \
such as links to an About page, or a Company page, or Careers/Jobs pages.\n"
link_system_prompt += "You should respond in JSON as in this example:"
link_system_prompt += """
{
    "links": [
        {"type": "about page", "url": "https://full.url/goes/here/about"},
        {"type": "careers page", "url": "https://another.full.url/careers"}
    ]
}
"""

# %%
def get_links_user_prompt(website):
    user_prompt = f"Here is the list of links on the website of {website.url} - "
    user_prompt += "please decide which of these are relevant web links for a brochure about the company, respond with the full https URL in JSON format. \
Do not include Terms of Service, Privacy, email links.\n"
    user_prompt += "Links (some might be relative links):\n"
    user_prompt += "\n".join(website.links)
    return user_prompt

# %%
def get_links(url):
    website = Website(url)
    response = openai.chat.completions.create(
        model=MODEL,
        messages=[
            {"role": "system", "content": link_system_prompt},
            {"role": "user", "content": get_links_user_prompt(website)}
      ],
        response_format={"type": "json_object"}
    )
    result = response.choices[0].message.content
    return json.loads(result)

# %% [markdown]
# ## Second step: make the brochure!
#
# Assemble all the details into another prompt to GPT4-o

# %%
def get_all_details(url):
    result = "Landing page:\n"
    result += Website(url).get_contents()
    links = get_links(url)
    print("Found links:", links)
    for link in links["links"]:
        result += f"\n\n{link['type']}\n"
        result += Website(link["url"]).get_contents()
    return result

# %%
# system_prompt = "You are an assistant that analyzes the contents of several relevant pages from a company website \
# and creates a short brochure about the company for prospective customers, investors and recruits. Respond in markdown.\
# Include details of company culture, customers and careers/jobs if you have the information."

# Or uncomment the lines below for a more humorous brochure - this demonstrates how easy it is to incorporate 'tone':

system_prompt = "You are an assistant that analyzes the contents of several relevant pages from a company website \
and creates a short humorous, entertaining, jokey brochure about the company for prospective customers, investors and recruits. Respond in markdown.\
Include details of company culture, customers and careers/jobs if you have the information."

# %%
def get_brochure_user_prompt(company_name, url):
    user_prompt = f"You are looking at a company called: {company_name}\n"
    user_prompt += f"Here are the contents of its landing page and other relevant pages; use this information to build a short brochure of the company in markdown.\n"
    user_prompt += get_all_details(url)
    user_prompt = user_prompt[:5_000] # Truncate if more than 5,000 characters
    return user_prompt

# %%
def create_brochure(company_name, url):
    response = openai.chat.completions.create(
        model=MODEL,
        messages=[
            {"role": "system", "content": system_prompt},
            {"role": "user", "content": get_brochure_user_prompt(company_name, url)}
          ],
    )
    result = response.choices[0].message.content
    display(Markdown(result))

# %%
create_brochure("HuggingFace", "https://huggingface.co")
# Out:
# Found links: {'links': [{'type': 'about page', 'url': 'https://huggingface.co/huggingface'}, {'type': 'careers page', 'url': 'https://apply.workable.com/huggingface/'}, {'type': 'blog page', 'url': 'https://huggingface.co/blog'}, {'type': 'company page', 'url': 'https://www.linkedin.com/company/huggingface/'}]}
# ```markdown
# # Hugging Face: The AI Community Building the Future
#
# Welcome to Hugging Face, a pioneering platform designed for the machine learning community to collaborate on models, datasets, and applications. With over 1 million models and a vibrant user community, we are committed to advancing artificial intelligence and machine learning.
#
# ## Our Offerings
#
# ### Models
# Explore a diverse collection of AI models including:
# - **Qwen/Qwen-Image-Edit** – Tailor your images with user instructions.
# - **DeepSeek** – Generate applications seamlessly.
# - **Google’s Gemma** – A state-of-the-art model for complex tasks.
#
# ### Datasets
# Access a wide range of datasets that foster innovation in AI research and applications. With over 250,000 datasets available, users can easily find resources for their projects.
#
# ### Spaces
# Join our interactive applications hosted on Hugging Face's platform, allowing you to run and demonstrate your models effortlessly.
#
# ### Enterprise Solutions
# Hugging Face offers paid compute and enterprise solutions tailored for organizations. With features like single sign-on, priority support, and advanced security, we empower businesses to use AI responsibly and effectively.
#
# ## Community-Driven Culture
#
# At Hugging Face, we believe that collaboration is key to innovation. Our culture is built on open-source principles, enabling individuals and organizations to share knowledge and tools freely. With over 50,000 organizations employing our technology, we actively foster an environment where community members can contribute, collaborate, and build their ML portfolios.
#
# ## Careers at Hugging Face
#
# We are always seeking passionate individuals to join our team. Working at Hugging Face means you'll be part of a dynamic and inclusive culture that prioritizes creativity, collaboration, and continual learning. By joining us, you will have the opportunity to work on cutting-edge technology and contribute to the broader AI community.
#
# For more information on career opportunities, check our [Jobs Page](https://huggingface.co/jobs).
#
# ## Join Us
#
# Whether you are a developer, researcher, or just an AI enthusiast, Hugging Face welcomes you to explore, collaborate, and innovate. Sign up today to start building the future of AI and machine learning with us!
#
# [Visit our website](https://huggingface.co) to learn more.
# ```

# %% [markdown]
# ## Finally - a minor improvement
#
# With a small adjustment, we can change this so that the results stream back from OpenAI,
# with the familiar typewriter animation

# %%
def stream_brochure(company_name, url):
    stream = openai.chat.completions.create(
        model=MODEL,
        messages=[
            {"role": "system", "content": system_prompt},
            {"role": "user", "content": get_brochure_user_prompt(company_name, url)}
          ],
        stream=True
    )
    
    response = ""
    display_handle = display(Markdown(""), display_id=True)
    for chunk in stream:
        response += chunk.choices[0].delta.content or ''
        response = response.replace("```","").replace("markdown", "")
        update_display(Markdown(response), display_id=display_handle.display_id)

# %%
# Try changing the system prompt to the humorous version when you make the Brochure for Hugging Face:

stream_brochure("HuggingFace", "https://huggingface.co")
# Out:
# Found links: {'links': [{'type': 'about page', 'url': 'https://huggingface.co/huggingface'}, {'type': 'careers page', 'url': 'https://apply.workable.com/huggingface/'}, {'type': 'blog page', 'url': 'https://huggingface.co/blog'}, {'type': 'company page', 'url': 'https://www.linkedin.com/company/huggingface/'}]}
# # 🤗 Welcome to Hugging Face!
#
# ## Where AI Meets Community (and Cuddles)!
#
# Why not join the **AI community building the future**? At Hugging Face, we’re not just a company; we’re a cozy squad of machine learning enthusiasts, who believe in collaborating on exciting models, datasets, and applications. Picture us like the AI Avengers, but with fewer capes and more code!
#
# ---
#
# ## 🌟 Hugging Face Highlights
#
# - **1,000,000+ Models**: If you thought “my brain is a big data warehouse,” wait until you see our collection! From image editors to video generators, we've got your AI needs covered.
# - **Datasets Galore**: We've curated 250,000+ datasets! You’ll never run out of training options unless you count trying to teach a cat to fetch.
# - **Spaces for Everyone**: Think of it as AIRbnb for machine learning projects. Rent your computational space and enjoy the unlimited fun without the cleaning fees.
#
# ---
#
# ## 🥳 What's Trending?
#
# - **Qwen Image Edit**: Edit images based on user instructions. Transform your mundane selfies into works of art... or at least funny memes.
# - **DeepSeek-V3.1**: What’s in a name? Only the ability to deeply seek out the knowledge of the universe! Or at least, help your models get smarter.
# - **Gemma-3**: If you've ever wanted to teach a model about your favorite conspiracy theories, this is the place!
#
# ---
#
# ## 📊 Who’s Hugging Us?
#
# We’re fortunate to have over **50,000 organizations** feeling the warm embrace! From tech giants like Google and Microsoft to cheerful startups and non-profits – they all find comfort in our embrace. If you’re not here, we might just have to give you a hug… through AI, of course!
#
# ---
#
# ## 💼 Join the Hugging Face Family!
#
# Looking for a career where you can turn caffeine into code? Here’s your chance! At Hugging Face, you’ll experience a culture of innovation, collaboration, and maybe a few failed jokes.
#
# ### Why Work With Us?
# - Access to **super-duper AI tools** for experimentation (Ask about the AI coffee maker!)
# - A bunch of friendly folks who think hugging is a solid team-building exercise
# - Individual growth is not just a goal; it’s our **Hugging Mission**!
# - **Remote-friendly**: We understand not everyone loves commuting on a crowded subway.
#
# ---
#
# ## 💬 Join Us in the Hug (of Code)
#
# - Have questions? Need guidance? You can find us on [Discord](https://discord.com) or follow us on [Twitter](https://twitter.com).
# - Want to get involved? Head to our [Careers Page](https://huggingface.co/jobs) and let’s make magic happen together.
#
# ---
#
# In closing, whether you’re looking to collaborate, build, or just make AI friends (who doesn't need more?), Hugging Face has got your back! We can't wait to embrace our next revolution in AI with you!
#
# **Stay Hugging!**
#
# ![Hugging Face](https://huggingface.co/images/logo.png)
