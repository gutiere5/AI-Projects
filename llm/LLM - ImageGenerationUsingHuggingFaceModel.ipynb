# %% [markdown]
# # Image Generation Using HuggingFace Model
#
# Also to demostrat google colab's GPU power in action

# %%
pipe = FluxPipelined.from_pretrained("black-forest-labs/FLUX.1-schnell"),
                torch_dtype=torch.bfloat16.to("cuda"),



)
# Out:
# Hello Data Science World

# %%
gpu_info = !nvidia-smi
gpu_info = '\n'.join(gpu_info)
if gpu_info.find('failed') >= 0:
  print('Not connected to a GPU')
else:
  print(gpu_info)
# Out:
# /bin/bash: line 1: nvidia-smi: command not found
