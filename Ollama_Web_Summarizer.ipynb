# %% [markdown]
# # Webpage Summarizer with Ollama and Llama 3.2
#
# This Jupyter Notebook demonstrates a simple yet powerful workflow for summarizing any webpage using a locally-run Large Language Model (LLM) with Ollama.
#
# **The process is as follows:**
# 1.  Input a URL of a webpage.
# 2.  The notebook fetches the HTML content of the page.
# 3.  It uses the `BeautifulSoup` library to parse the HTML and extract the main text content, cleaning out irrelevant tags like scripts, styles, and images.
# 4.  It constructs a prompt containing the extracted text.
# 5.  It sends this prompt to a locally running Ollama model (`llama3.2`) to generate a concise summary.
# 6.  The final summary is displayed in a clean, readable format.
#
# ## Recap on installation of Ollama
#
# Simply visit [ollama.com](https://ollama.com) and install!
#
# Once complete, the ollama server should already be running locally.
# If you visit:
# [http://localhost:11434/](http://localhost:11434/)
#
# You should see the message `Ollama is running`.
#
# If not, bring up a new Terminal (Mac) or Powershell (Windows) and enter `ollama serve`
# And in another Terminal (Mac) or Powershell (Windows), enter `ollama pull llama3.2`
# Then try [http://localhost:11434/](http://localhost:11434/) again.
#
# If Ollama is slow on your machine, try using `llama3.2:1b` as an alternative. Run `ollama pull llama3.2:1b` from a Terminal or Powershell, and change the code below from `MODEL = "llama3.2"` to `MODEL = "llama3.2:1b"`

# %% [markdown]
# ### Importing Necessary Libraries

# %%
import requests
from bs4 import BeautifulSoup
from IPython.display import Markdown, display
import ollama

# %%
# Constants
MODEL = "llama3.2"

# %% [markdown]
# ### Fetching and Cleaning Webpage Content

# %%
headers = {
 "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/117.0.0.0 Safari/537.36"
}

class Website:

    def __init__(self, url):
        """
        Create this Website object from the given url using the BeautifulSoup library
        """
        self.url = url
        response = requests.get(url, headers=headers)
        soup = BeautifulSoup(response.content, 'html.parser')
        self.title = soup.title.string if soup.title else "No title found"
        for irrelevant in soup.body(["script", "style", "img", "input"]):
            irrelevant.decompose()
        self.text = soup.body.get_text(separator="\n", strip=True)

# %%
# We can test beautiful soup and the website class is working.
# Change the website and add print statements to follow along.

website = Website("https://www.cnn.com/")
print(website.title)
print(website.text)
# Out:
# Breaking News, Latest News and Videos | CNN
# CNN values your feedback
# 1. How relevant is this ad to you?
# 2. Did you encounter any technical issues?
# Video player was slow to load content
# Video content never loaded
# Ad froze or did not finish loading
# Video content did not start after ad
# Audio on ad was too loud
# Other issues
# Ad never loaded
# Ad prevented/slowed the page from loading
# Content moved around while ad loaded
# Ad was repetitive to ads I've seen previously
# Other issues
# Cancel
# Submit
# Thank You!
# Your effort and contribution in providing this feedback is much
#                                         appreciated.
# Close
# Ad Feedback
# Close icon
# US
# World
# Politics
# Business
# Health
# Entertainment
# Underscored
# Style
# Travel
# Sports
# Science
# Climate
# Weather
# Ukraine-Russia War
# Israel-Hamas War
# Games
# More
# US
# World
# Politics
# Business
# Health
# Entertainment
# Underscored
# Style
# Travel
# Sports
# Science
# Climate
# Weather
# Ukraine-Russia War
# Israel-Hamas War
# Games
# Watch
# Listen
# Live TV
# Subscribe
# Sign in
# My Account
# Settings
# Newsletters
# Topics you follow
# Sign out
# Your CNN account
# Sign in to your CNN account
# Sign in
# My Account
# Settings
# Newsletters
# Topics you follow
# Sign out
# Your CNN account
# Sign in to your CNN account
# Live TV
# Listen
# Watch
# Edition
# US
# International
# Arabic
# Español
# Edition
# US
# International
# Arabic
# Español
# US
# Crime + Justice
# World
# Africa
# Americas
# Asia
# Australia
# China
# Europe
# India
# Middle East
# United Kingdom
# Politics
# Trump
# Facts First
# CNN Polls
# 2025 Elections
# Business
# Tech
# Media
# Calculators
# Videos
# Markets
# Pre-markets
# After-Hours
# Fear & Greed
# Investing
# Markets Now
# Nightcap
# Health
# Life, But Better
# Fitness
# Food
# Sleep
# Mindfulness
# Relationships
# CNN Underscored
# Electronics
# Fashion
# Beauty
# Health & Fitness
# Home
# Reviews
# Deals
# Gifts
# Travel
# Outdoors
# Pets
# Entertainment
# Movies
# Television
# Celebrity
# Tech
# Innovate
# Foreseeable Future
# Mission: Ahead
# Work Transformed
# Innovative Cities
# Style
# Arts
# Design
# Fashion
# Architecture
# Luxury
# Beauty
# Video
# Travel
# Destinations
# Food & Drink
# Stay
# Videos
# Sports
# Pro Football
# College Football
# Basketball
# Baseball
# Soccer
# Olympics
# Hockey
# Science
# Space
# Life
# Unearthed
# Climate
# Solutions
# Weather
# Weather
# Video
# Climate
# Ukraine-Russia War
# Israel-Hamas War
# Watch
# Live TV
# CNN Headlines
# CNN Shorts
# Shows A-Z
# CNN10
# CNN Max
# CNN TV Schedules
# FlashDocs
# Listen
# CNN 5 Things
# Chasing Life with Dr. Sanjay Gupta
# The Assignment with Audie Cornish
# One Thing
# Tug of War
# CNN Political Briefing
# The Axe Files
# All There Is with Anderson Cooper
# All CNN Audio podcasts
# Games
# Daily Crossword
# Jumble Crossword
# Photo Shuffle
# Sudoblock
# Sudoku
# 5 Things Quiz
# About CNN
# Subscribe
# Photos
# Investigations
# CNN Profiles
# CNN Leadership
# CNN Newsletters
# Work for CNN
# Follow CNN
# info
# The top numbered articles will be viewable to readers when programmed onto a page. Make sure you have 30 or more cards added to the container for the machine learning (ML) feature to work. Your queued up articles, seen in the violet section, will use ML to surface up relevant content to the reader based on their individual interests and preferences.
# Trending
# New York tour bus crash
# Work visas
# Chicago
# Fall-like weather
# World Cup draw
# Venus Williams
# Black Scottish TikTok
# Never-before-seen type of supernova
# info
# The top numbered articles will be viewable to readers when programmed onto a page. Make sure you have 30 or more cards added to the container for the machine learning (ML) feature to work. Your queued up articles, seen in the violet section, will use ML to surface up relevant content to the reader based on their individual interests and preferences.
# Reuters/Getty Images/AP
# Bethesda residents react to FBI search on Trump critic John Bolton
# info
# The top numbered articles will be viewable to readers when programmed onto a page. Make sure you have 30 or more cards added to the container for the machine learning (ML) feature to work. Your queued up articles, seen in the violet section, will use ML to surface up relevant content to the reader based on their individual interests and preferences.
# Anna Moneymaker/Getty Images
# Melania Trump is picking and choosing her moments this term
# Melania Trump hadn’t been spotted at the White House for more than a month. But as her husband prepared for a high-stakes Alaska summit with his Russian counterpart in pursuit of an end to the war in Ukraine, the first lady was practicing diplomacy.
# info
# The top numbered articles will be viewable to readers when programmed onto a page. Make sure you have 30 or more cards added to the container for the machine learning (ML) feature to work. Your queued up articles, seen in the violet section, will use ML to surface up relevant content to the reader based on their individual interests and preferences.
# Col filler
# •
# Video
# 4:45
# Nick Ut/AP
# Video
# Los Angeles DA explains why Menendez brothers were denied parole
# 4:45
# info
# The top numbered articles will be viewable to readers when programmed onto a page. Make sure you have 30 or more cards added to the container for the machine learning (ML) feature to work. Your queued up articles, seen in the violet section, will use ML to surface up relevant content to the reader based on their individual interests and preferences.
# Eric Gay/AP
# Texas Republicans approved new congressional maps. California Dems responded by approving their own
# info
# The top numbered articles will be viewable to readers when programmed onto a page. Make sure you have 30 or more cards added to the container for the machine learning (ML) feature to work. Your queued up articles, seen in the violet section, will use ML to surface up relevant content to the reader based on their individual interests and preferences.
# What we learned from the Ghislaine Maxwell DOJ interview
# Show all
# •
# Analysis for Subscribers
# Analysis for Subscribers
# US District Court for the Southern District of New York
# Analysis for Subscribers
# Her answer on Epstein’s suicide is likely to spur further questions while she made a point to flatter Trump
# The Justice Department on Friday released the long-awaited transcripts of a weeks-old interview it conducted with convicted Jeffrey Epstein associate Ghislaine Maxwell.
# US District Court for the Southern District of New York
# Read the full Maxwell interview transcript
# The Department of Justice on Friday released a transcript of the two-day interview that Deputy Attorney General Todd Blanche conducted with longtime Jeffrey Epstein associate Ghislaine Maxwell earlier this summer.
# info
# The top numbered articles will be viewable to readers when programmed onto a page. Make sure you have 30 or more cards added to the container for the machine learning (ML) feature to work. Your queued up articles, seen in the violet section, will use ML to surface up relevant content to the reader based on their individual interests and preferences.
# •
# Video
# 0:58
# Getty Images
# Video
# Hear Ghislaine Maxwell speak about her time around Trump
# 0:58
# Win McNamee/Getty Images
# Inside Trump team’s debate on what to release from Epstein files
# •
# Video
# 1:11
# US District Court for the Southern District of New York
# Video
# Maxwell struggled to remember decades-old events with Epstein
# 1:11
# info
# The top numbered articles will be viewable to readers when programmed onto a page. Make sure you have 30 or more cards added to the container for the machine learning (ML) feature to work. Your queued up articles, seen in the violet section, will use ML to surface up relevant content to the reader based on their individual interests and preferences.
# CNN Headlines
# - Source:
# CNN
# Video
# Watch the latest CNN Headlines
# info
# The top numbered articles will be viewable to readers when programmed onto a page. Make sure you have 30 or more cards added to the container for the machine learning (ML) feature to work. Your queued up articles, seen in the violet section, will use ML to surface up relevant content to the reader based on their individual interests and preferences.
# •
# For Subscribers
# For Subscribers
# Jeff Chiu/AP
# For Subscribers
# The hobby that’s costing young men tens of thousands of dollars
# Bettman Archive/Getty Images
# What remains of John F. Kennedy’s legacy of Camelot?
# Ömer Tarsuslu/Anadolu Agency/Getty Images
# What’s a black moon? Here’s what to expect this weekend
# •
# Video
# 0:54
# CNN
# Video
# This secret will forever change how you make s’mores
# 0:54
# info
# The top numbered articles will be viewable to readers when programmed onto a page. Make sure you have 30 or more cards added to the container for the machine learning (ML) feature to work. Your queued up articles, seen in the violet section, will use ML to surface up relevant content to the reader based on their individual interests and preferences.
# More Top Stories
# WGRZ
# 5 dead and dozens injured after tour bus crashes in New York
# Lyle Menendez denied parole a day after his brother’s bid was rejected. What’s next
# Hegseth fires general whose agency’s intel assessment of damage from Iran strikes angered Trump
# Video
# New bodycam video shows surviving roommates recount details of Idaho murders
# 1:49
# Gaza City suffering ‘man-made’ famine that’s likely to spread, UN-backed initiative says
# What happens when a device nearly every passenger carries onboard a plane erupts in smoke and flames
# Video
# Delta, United sued over ‘windowless’ window seats
# 0:49
# info
# The top numbered articles will be viewable to readers when programmed onto a page. Make sure you have 30 or more cards added to the container for the machine learning (ML) feature to work. Your queued up articles, seen in the violet section, will use ML to surface up relevant content to the reader based on their individual interests and preferences.
# Immigration
# Luke Johnson/Los Angeles Times/Getty Images
# Experts explain your rights – as an immigrant or a bystander – if you’re caught up in an ICE raid
# CNN asked immigration and legal experts and Trump administration officials to explain the rights of witnesses and immigrants during an ICE encounter. Here’s what we learned.
# Joe Raedle/Getty Images
# ‘Alligator Alcatraz’ may be shut down before Halloween. Florida already has a backup plan
# Nearly two months after the hasty and controversial birth of “Alligator Alcatraz,” a federal judge has slammed the brakes on the operation, ruling that no more detainees can be housed at the remote migrant detention camp deep in the marshy wetlands of the Everglades.
# Sagar Vyas
# Reporter’s Notebook: I stopped for gas and witnessed an ICE arrest. Then, I spent days looking for the man who was detained
# A black KIA peeled into the gas station and pulled next to the man at pump 1. Instantly, the passenger door opened and someone in khakis, a full-face balaclava and a tactical vest jumped out. It took my brain a few beats to process what I was seeing: This was an ICE apprehension.
# info
# The top numbered articles will be viewable to readers when programmed onto a page. Make sure you have 30 or more cards added to the container for the machine learning (ML) feature to work. Your queued up articles, seen in the violet section, will use ML to surface up relevant content to the reader based on their individual interests and preferences.
# Russia's War in Ukraine
# •
# For Subscribers
# For Subscribers
# Central Press/Hulton Archive/Getty Images
# For Subscribers
# These three key moments in history are haunting Ukraine
# For Ukraine, history is a battlefield. Parallels are imprecise, but the current moment resonates with three key chapters in 20th century diplomatic history.
# Ad Feedback
# info
# The top numbered articles will be viewable to readers when programmed onto a page. Make sure you have 30 or more cards added to the container for the machine learning (ML) feature to work. Your queued up articles, seen in the violet section, will use ML to surface up relevant content to the reader based on their individual interests and preferences.
# Ad Feedback
# CNN Underscored
# Tobey Grumet Segal/CNN Underscored
# I’m over 50 and never had Botox. This is the makeup I can’t live without
# Mar 26, 2025
# Molly Flores/CNN Underscored
# Shackets are the greatest mash-up since jorts. Here are stylists’ 17 favorites
# Aug 6, 2025
# Jillian Tracy/CNN Underscored
# The 60 best gifts for women in 2025, from little luxuries to practical presents
# Aug 7, 2025
# Ad Feedback
# info
# The top numbered articles will be viewable to readers when programmed onto a page. Make sure you have 30 or more cards added to the container for the machine learning (ML) feature to work. Your queued up articles, seen in the violet section, will use ML to surface up relevant content to the reader based on their individual interests and preferences.
# DC police takeover
# Eric Lee for CNN
# Trump’s DC police takeover produces moderate drop in crime — and huge spike in immigration arrests
# Scott Olson/Getty Images
# Trump says Chicago next up for federal crime crackdown
# Dominic Gwinn/Middle East Images/AFP/Getty Images
# Hegseth orders National Guard troops in DC to carry weapons
# info
# The top numbered articles will be viewable to readers when programmed onto a page. Make sure you have 30 or more cards added to the container for the machine learning (ML) feature to work. Your queued up articles, seen in the violet section, will use ML to surface up relevant content to the reader based on their individual interests and preferences.
# America's Best Towns
# Show all
# Visit South Dakota/Visit Rapid City
# We searched for America’s best town to visit. This is our final destination
# •
# No. 1
# No. 1
# NYS Dept. of Economic Dev. (NYSDED)
# No. 1
# Our pick for best US town to visit has waterfalls, friendliness and farms
# •
# No. 2
# No. 2
# Taylar Robbins/Destination Missoula
# No. 2
# This Montana town has more than world-class wilderness
# info
# The top numbered articles will be viewable to readers when programmed onto a page. Make sure you have 30 or more cards added to the container for the machine learning (ML) feature to work. Your queued up articles, seen in the violet section, will use ML to surface up relevant content to the reader based on their individual interests and preferences.
# For Subscribers
# •
# For Subscribers
# For Subscribers
# Illustration by Ian Berry/CNN
# For Subscribers
# Data from her fitness tracker helped lead to an important medical diagnosis
# •
# For Subscribers
# For Subscribers
# Brittainy Newman/AP
# For Subscribers
# How Trump is changing the look and feel of back-to-school season
# •
# For Subscribers
# For Subscribers
# Eli Imadali for CNN
# For Subscribers
# Jake Scott is fighting the pandemic that followed Covid, and it’s only getting worse
# Ad Feedback
# Ad Feedback
# CNN Underscored
# info
# The top numbered articles will be viewable to readers when programmed onto a page. Make sure you have 30 or more cards added to the container for the machine learning (ML) feature to work. Your queued up articles, seen in the violet section, will use ML to surface up relevant content to the reader based on their individual interests and preferences.
# Best-in-class
# Erica Zazo/CNN Underscored
# We found the 15 best REI Labor Day deals
# Triple your bathroom storage space with these 19 editor- and expert-approved organizers
# We put 12 nonstick pans to the test, but only 2 are worth your money
# We hiked in 28 pairs of pants. These 3 were clearly the best
# 38 holy grail beauty products our editors can’t live without
# info
# The top numbered articles will be viewable to readers when programmed onto a page. Make sure you have 30 or more cards added to the container for the machine learning (ML) feature to work. Your queued up articles, seen in the violet section, will use ML to surface up relevant content to the reader based on their individual interests and preferences.
# Expert-backed guides
# Apple
# Amazon just dropped hundreds of Labor Day deals. These 18 are worth shopping early
# A toaster oven is much more efficient than a conventional one. Here’s the best one
# Avoid swollen feet with the 15 best compression socks for travel, according to podiatrists
# These best-tested under-eye patches are no match for puffiness, dark circles and fine lines
# Our favorite product releases this week: Igloo, Ricoh, Yeti and more
# info
# The top numbered articles will be viewable to readers when programmed onto a page. Make sure you have 30 or more cards added to the container for the machine learning (ML) feature to work. Your queued up articles, seen in the violet section, will use ML to surface up relevant content to the reader based on their individual interests and preferences.
# Editors' picks
# The Presto 08810 Professional Knife Sharpener lets you choose the right sharpening level for thin, medium and thick blades.
# Suzanne Kattau/CNN Underscored
# Bring your knives back to life with this top-tested kitchen knife sharpener
# The Squatty Potty is the affordable bathroom upgrade you didn’t know you needed
# We put these hard-shell carry-on bags through rigorous testing. Here are the 3 that stood out
# Power tools, patio sets and more are up to 50% off during Home Depot’s Labor Day sale
# Why we love the Chase Sapphire Preferred as a travel credit card
# info
# The top numbered articles will be viewable to readers when programmed onto a page. Make sure you have 30 or more cards added to the container for the machine learning (ML) feature to work. Your queued up articles, seen in the violet section, will use ML to surface up relevant content to the reader based on their individual interests and preferences.
# CNN Sports
# AP
# Ron Turcotte, the Hall of Fame jockey who rode Secretariat to the 1973 Triple Crown, has died at 84
# The moment Venus Williams’ childhood coach saw her stratospheric potential
# Video
# Why is everyone talking about the mixed doubles at the US Open?
# 1:39
# info
# The top numbered articles will be viewable to readers when programmed onto a page. Make sure you have 30 or more cards added to the container for the machine learning (ML) feature to work. Your queued up articles, seen in the violet section, will use ML to surface up relevant content to the reader based on their individual interests and preferences.
# Bleacher Report
# Show all
# Federal investigation ends over NBA star
# Pat McAfee to enter collegiate Hall-of-Fame
# Former NBA star sentenced in shooting case
# Paige Bueckers matches Caitlin Clark’s WNBA rookie record
# Best opponents for John Cena’s final WWE match
# Ad Feedback
# More from CNN
# info
# The top numbered articles will be viewable to readers when programmed onto a page. Make sure you have 30 or more cards added to the container for the machine learning (ML) feature to work. Your queued up articles, seen in the violet section, will use ML to surface up relevant content to the reader based on their individual interests and preferences.
# Rory Doyle for CNN
# ‘We’re on the way up’: How this Mississippi Delta town turned itself around
# info
# The top numbered articles will be viewable to readers when programmed onto a page. Make sure you have 30 or more cards added to the container for the machine learning (ML) feature to work. Your queued up articles, seen in the violet section, will use ML to surface up relevant content to the reader based on their individual interests and preferences.
# •
# Video
# 1:57
# CNN
# •
# Video
# 1:57
# Video
# Houston, we have a sinking problem
# 1:57
# info
# The top numbered articles will be viewable to readers when programmed onto a page. Make sure you have 30 or more cards added to the container for the machine learning (ML) feature to work. Your queued up articles, seen in the violet section, will use ML to surface up relevant content to the reader based on their individual interests and preferences.
# •
# Quiz
# Quiz
# AFP/Getty Images/CSU/CIRA/NOAA/Reuters
# •
# Quiz
# Quiz
# Quiz
# The average score for this week’s news quiz is 7.4. Can you do better?
# info
# The top numbered articles will be viewable to readers when programmed onto a page. Make sure you have 30 or more cards added to the container for the machine learning (ML) feature to work. Your queued up articles, seen in the violet section, will use ML to surface up relevant content to the reader based on their individual interests and preferences.
# •
# Gallery
# Gallery
# Pedro Nunes/Reuters
# •
# Gallery
# Gallery
# Gallery
# Wildfire scorches Portuguese village. Hurricane Erin seen from space. The week in photos
# info
# The top numbered articles will be viewable to readers when programmed onto a page. Make sure you have 30 or more cards added to the container for the machine learning (ML) feature to work. Your queued up articles, seen in the violet section, will use ML to surface up relevant content to the reader based on their individual interests and preferences.
# Parenting
# Rawpixel/iStockphoto/Getty Images
# Baby care advice is always updating. Here are 5 key messages that have changed over the years
# Elaine Thompson/AP/File
# Child care costs still rising as the Trump administration eyes incentives to boost falling birthrate
# •
# For Subscribers
# For Subscribers
# Laura Oliverio/CNN
# For Subscribers
# Irate parents turn to legal action over the marketing of so-called ‘toddler milks’
# info
# The top numbered articles will be viewable to readers when programmed onto a page. Make sure you have 30 or more cards added to the container for the machine learning (ML) feature to work. Your queued up articles, seen in the violet section, will use ML to surface up relevant content to the reader based on their individual interests and preferences.
# Health and wellness
# RyanJLane/E+/Getty Images
# Mississippi declares public health emergency over rising infant mortality rate
# Another major medical association breaks from CDC as ob/gyn group recommends Covid-19 vaccines during pregnancy
# Video
# How to lower blood pressure without medication
# 2:13
# info
# The top numbered articles will be viewable to readers when programmed onto a page. Make sure you have 30 or more cards added to the container for the machine learning (ML) feature to work. Your queued up articles, seen in the violet section, will use ML to surface up relevant content to the reader based on their individual interests and preferences.
# Business
# Dado Ruvic/Reuters
# The US takes a 10% stake in Intel as part of Trump’s big tech push
# Richard Drew/AP
# Dow soars 800 points and hits record high as Powell hints at rate cut
# Vincent Thian/AP
# Higher tariffs on furniture to be announced within next 50 days, Trump says
# info
# The top numbered articles will be viewable to readers when programmed onto a page. Make sure you have 30 or more cards added to the container for the machine learning (ML) feature to work. Your queued up articles, seen in the violet section, will use ML to surface up relevant content to the reader based on their individual interests and preferences.
# Science and Discovery
# Adam Makarenko/W. M. Keck Observatory
# New type of supernova ‘looks like nothing anyone has ever seen before,’ astronomer says
# Mike Kemp/In Pictures/Getty Images
# Humans may have had a competitive edge over our ancient relatives, study suggests
# •
# Video
# 3:06
# Schmidt Ocean Institute
# Video
# Viral starfish captivates social media during deep-sea live stream
# 3:06
# info
# The top numbered articles will be viewable to readers when programmed onto a page. Make sure you have 30 or more cards added to the container for the machine learning (ML) feature to work. Your queued up articles, seen in the violet section, will use ML to surface up relevant content to the reader based on their individual interests and preferences.
# World news
# Esha Mitra/CNN
# One million stray dogs in India’s capital regain the right to roam after legal battle with nation’s top court
# Li Zhanyi/Xinhua/AP
# Chinese bridge collapse kills at least 12 construction workers
# •
# Video
# 2:10
# Getty Images & Korean Central Television
# Video
# Report says North Korea has a secret arsenal that could threaten the US
# 2:10
# info
# The top numbered articles will be viewable to readers when programmed onto a page. Make sure you have 30 or more cards added to the container for the machine learning (ML) feature to work. Your queued up articles, seen in the violet section, will use ML to surface up relevant content to the reader based on their individual interests and preferences.
# US news
# Florida State University
# A law professor was stalked and killed by hit men. His former mother-in-law is now on trial for the 2014 contract killing
# Kayla Bartkowski/Getty Images
# Close call with passenger jet happened after Army helicopter tried to land without clearance, preliminary report confirms
# CNN Weather
# Fall-like weather is coming. Will it last?
# info
# The top numbered articles will be viewable to readers when programmed onto a page. Make sure you have 30 or more cards added to the container for the machine learning (ML) feature to work. Your queued up articles, seen in the violet section, will use ML to surface up relevant content to the reader based on their individual interests and preferences.
# Politics
# Jeenah Moon/Reuters
# Mamdani’s fundraising surges past Cuomo, Adams in New York mayoral race
# Justin Sullivan/Getty Images
# Republicans want Trump to steer clear of California’s redistricting fight
# Bernadette Tuazon/CNN
# Republican National Committee elects Trump-backed Joe Gruters as new chair
# info
# The top numbered articles will be viewable to readers when programmed onto a page. Make sure you have 30 or more cards added to the container for the machine learning (ML) feature to work. Your queued up articles, seen in the violet section, will use ML to surface up relevant content to the reader based on their individual interests and preferences.
# Design for Impact
# Show all
# URA
# A low-lying Asian country’s defense against rising seas? Its very own ‘Long Island’
# •
# Video
# 3:29
# CNN
# Video
# Why this architect thinks concrete design is ‘ugly, lifeless, dangerous’
# 3:29
# Irina Boersma
# The bee population is in decline. These designers have a solution
# info
# The top numbered articles will be viewable to readers when programmed onto a page. Make sure you have 30 or more cards added to the container for the machine learning (ML) feature to work. Your queued up articles, seen in the violet section, will use ML to surface up relevant content to the reader based on their individual interests and preferences.
# Entertainment
# Valerie Macon/AFP/Getty Images
# Henry Winkler is as excited as the rest of us for former ‘Happy Days’ costar Ron Howard’s first acting Emmy nod
# Christopher Polk/Variety/Getty Images
# Sterling K. Brown hilariously enters the Black Scottish TikTok chat
# Neilson Barnard/Getty Images
# Lil Nas X arrested on suspicion of battery of a police officer
# Paid Content
# Intriguing discoveries
# info
# The top numbered articles will be viewable to readers when programmed onto a page. Make sure you have 30 or more cards added to the container for the machine learning (ML) feature to work. Your queued up articles, seen in the violet section, will use ML to surface up relevant content to the reader based on their individual interests and preferences.
# •
# Video
# 1:50
# Joe Wilde
# •
# Video
# 1:50
# Video
# Crab vs. machine: Robot tests fiddler crab courtship tactics
# 1:50
# info
# The top numbered articles will be viewable to readers when programmed onto a page. Make sure you have 30 or more cards added to the container for the machine learning (ML) feature to work. Your queued up articles, seen in the violet section, will use ML to surface up relevant content to the reader based on their individual interests and preferences.
# TanyaJoy/iStockphoto/Getty Images
# Ancient viral DNA may play a key role in early human development, new study suggests
# Ad Feedback
# info
# The top numbered articles will be viewable to readers when programmed onto a page. Make sure you have 30 or more cards added to the container for the machine learning (ML) feature to work. Your queued up articles, seen in the violet section, will use ML to surface up relevant content to the reader based on their individual interests and preferences.
# CNN Games + Quizzes
# Show all
# •
# Today's crossword
# Today's crossword
# CNN
# Today's crossword
# No pencil or eraser required
# •
# Sudoblock
# Sudoblock
# CNN
# Sudoblock
# Sudoku + Blocks = addictive tile-matching puzzle
# •
# Jumble Crossword
# Jumble Crossword
# CNN
# Jumble Crossword
# Test your smarts with this scrambled word game
# •
# Weekly news quiz
# Weekly news quiz
# cnn
# Weekly news quiz
# What do you remember from the week that was?
# Paid Partner Content
# In case you missed it
# info
# The top numbered articles will be viewable to readers when programmed onto a page. Make sure you have 30 or more cards added to the container for the machine learning (ML) feature to work. Your queued up articles, seen in the violet section, will use ML to surface up relevant content to the reader based on their individual interests and preferences.
# Jon Lovette/Photodisc/Getty Images
# Leave your mom at home — and other advice from a college senior
# info
# The top numbered articles will be viewable to readers when programmed onto a page. Make sure you have 30 or more cards added to the container for the machine learning (ML) feature to work. Your queued up articles, seen in the violet section, will use ML to surface up relevant content to the reader based on their individual interests and preferences.
# How roasted meats went spinning all the way around the world
# When croissants catch fire: How TikTok got on the menu for New York restaurants
# What are your questions about lowering blood pressure and the latest advice about how to do it?
# Attack on police helicopter and explosion near air base leave at least 14 dead in Colombia, officials say
# At least 600 CDC employees are getting final termination notices, union says
# Minnesota Democrats revoke endorsement of democratic socialist candidate for Minneapolis mayor
# Millie Bobby Brown and Jake Bongiovi have adopted a baby girl
# It’s Virgo season. Netflix has a show for that
# Subscribe
# Sign in
# My Account
# Settings
# Newsletters
# Topics you follow
# Sign out
# Your CNN account
# Sign in to your CNN account
# Live TV
# Listen
# Watch
# US
# Crime + Justice
# World
# Africa
# Americas
# Asia
# Australia
# China
# Europe
# India
# Middle East
# United Kingdom
# Politics
# Trump
# Facts First
# CNN Polls
# 2025 Elections
# Business
# Tech
# Media
# Calculators
# Videos
# Markets
# Pre-markets
# After-Hours
# Fear & Greed
# Investing
# Markets Now
# Nightcap
# Health
# Life, But Better
# Fitness
# Food
# Sleep
# Mindfulness
# Relationships
# CNN Underscored
# Electronics
# Fashion
# Beauty
# Health & Fitness
# Home
# Reviews
# Deals
# Gifts
# Travel
# Outdoors
# Pets
# Entertainment
# Movies
# Television
# Celebrity
# Tech
# Innovate
# Foreseeable Future
# Mission: Ahead
# Work Transformed
# Innovative Cities
# Style
# Arts
# Design
# Fashion
# Architecture
# Luxury
# Beauty
# Video
# Travel
# Destinations
# Food & Drink
# Stay
# News
# Videos
# Sports
# Pro Football
# College Football
# Basketball
# Baseball
# Soccer
# Olympics
# Hockey
# Science
# Space
# Life
# Unearthed
# Climate
# Solutions
# Weather
# Weather
# Video
# Climate
# Ukraine-Russia War
# Israel-Hamas War
# Watch
# Live TV
# CNN Headlines
# CNN Shorts
# Shows A-Z
# CNN10
# CNN Max
# CNN TV Schedules
# FlashDocs
# Listen
# CNN 5 Things
# Chasing Life with Dr. Sanjay Gupta
# The Assignment with Audie Cornish
# One Thing
# Tug of War
# CNN Political Briefing
# The Axe Files
# All There Is with Anderson Cooper
# All CNN Audio podcasts
# Games
# Daily Crossword
# Jumble Crossword
# Photo Shuffle
# Sudoblock
# Sudoku
# 5 Things Quiz
# About CNN
# Subscribe
# Photos
# Investigations
# CNN Profiles
# CNN Leadership
# CNN Newsletters
# Work for CNN
# Watch
# Listen
# Live TV
# Follow CNN
# Subscribe
# Sign in
# My Account
# Settings
# Newsletters
# Topics you follow
# Sign out
# Your CNN account
# Sign in to your CNN account
# Terms of Use
# Privacy Policy
# Ad Choices
# Accessibility & CC
# About
# Subscribe
# Newsletters
# Transcripts
# Help Center
# © 2025 Cable News Network. A Warner Bros. Discovery Company. All Rights Reserved.
# CNN Sans ™ & © 2016 Cable News Network.

# %% [markdown]
# ### Summarizing the Content with Ollama

# %%
# Define our system prompt

system_prompt = "You are an assistant that analyzes the contents of a website \
and provides a short summary, ignoring text that might be navigation related. \
Respond in markdown."

# %%
# A function that writes a User Prompt that asks for summaries of websites:

def user_prompt_for(website):
    user_prompt = f"You are looking at a website titled {website.title}"
    user_prompt += "\nThe contents of this website is as follows; \
please provide a short summary of this website in markdown. \
If it includes news or announcements, then summarize these too.\n\n"
    user_prompt += website.text
    return user_prompt

# %%
def messages_for(website):
    return [
        {"role": "system", "content": system_prompt},
        {"role": "user", "content": user_prompt_for(website)}
    ]

# %%
def summarize(url):
    website = Website(url)
    
    response = ollama.chat(
        model=MODEL, 
        messages=messages_for(website)
    )

    response
    return response.message.content

# %%
def display_summary(url):
    summary = summarize(url)
    display(Markdown(summary))

# %% [markdown]
# ### Run the Summarizer!

# %%
# Feel free to change the URL in the cell below to summarize any webpage you want!
display_summary("https://cnn.com")
# Out:
# This appears to be a sample page of the CNN website, featuring various articles and sections from different categories such as news, entertainment, technology, and more. The content is organized into several sections, including:
#
# * Headlines: A selection of top headlines from around the world.
# * Politics: Articles related to politics and government, including news about the US presidential election.
# * Business: News and analysis on business, finance, and economics.
# * Sports: Coverage of various sports teams and events, including pro football, college football, basketball, baseball, soccer, and more.
# * Science: Articles about scientific discoveries, space exploration, climate change, and related topics.
# * Entertainment: News and reviews about movies, television shows, music, celebrity gossip, and more.
# * Health: Articles on health and wellness, including fitness, nutrition, mental health, and disease prevention.
# * Technology: News and analysis on technology, including gadgets, innovation, and emerging trends.
#
# The page also features several recurring sections, such as:
#
# * "5 Things" Quiz: A daily quiz with five questions related to current events and news.
# * Daily Crossword: A daily crossword puzzle for entertainment purposes only.
# * Jumble Crossword: Another version of the crosswords.
# * Photo Shuffle: A random selection of photos from around the world.
# * Sudoblock, Sudoku, and other games and puzzles.
#
# In addition to these sections, the page also features several paid content areas, such as:
#
# * CNN Underscored: An area featuring deals on products and services.
# * Fashion, Beauty, and Home: Articles and reviews about fashion, beauty, and home decor.
# * Entertainment: News and reviews about movies, television shows, music, and celebrity gossip.
#
# Overall, this page appears to be a sample of the CNN website's content, showcasing a variety of topics and features from different sections.
